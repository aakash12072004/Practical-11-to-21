# %%
import pandas as pd
import matplotlib.pyplot as plt# 1. Load Tabular Data
# Use pd.read_csv("your_file.csv") for external files
df = pd.read_csv("scottish_hills.csv")
# 2. Structured Summarization
print("--- Dataset Snapshot ---")
print(df.head(10)) # First 10 rows for initial interpretation
print("\n--- Summary Statistics ---")
# Generates mean, median, min, max, and std deviation
print(df.describe())
# 3. Categorical Interpretation
# Example: Grouping by a category to see trends (e.g., Average height per Region)
if 'Region' in df.columns:
 print("\n--- Region-wise Summary ---")
 print(df.groupby('Region')['Height'].mean())
# 4. Visual Interpretation (Box Plot)
# Useful for seeing distributions and identifying outliers
df.boxplot(column='Height')
plt.title('Distribution of Heights')
plt.ylabel('Meters')
plt.show()
# Out:
# --- Dataset Snapshot ---
#                     Hill  Height  Latitude  Longitude      Region
# 0              Ben Nevis    1345   56.7969    -5.0036   Highlands
# 1             Ben Macdui    1309   57.0704    -3.6683  Cairngorms
# 2              Braeriach    1296   57.0783    -3.7283  Cairngorms
# 3             Cairn Toul    1291   57.0542    -3.7100  Cairngorms
# 4  Sgòr an Lochain Uaine    1258   57.0570    -3.7260  Cairngorms
# 5             Cairn Gorm    1245   57.1167    -3.6444  Cairngorms
# 6            Aonach Beag    1234   56.8333    -4.5290   Highlands
# 7             Aonach Mòr    1221   56.8167    -4.9610   Highlands
# 8         Carn Mòr Dearg    1220   56.8052    -4.9866   Highlands
# 9             Ben Lawers    1214   56.5447    -4.2200  Perthshire
#
# --- Summary Statistics ---
#             Height   Latitude  Longitude
# count    10.000000  10.000000   10.00000
# mean   1263.300000  56.917340   -4.21772
# std      44.617012   0.185726    0.59887
# min    1214.000000  56.544700   -5.00360
# 25%    1224.250000  56.808075   -4.85300
# 50%    1251.500000  56.943750   -3.97415
# 75%    1294.750000  57.067050   -3.71400
# max    1345.000000  57.116700   -3.64440
#
# --- Region-wise Summary ---
# Region
# Cairngorms    1279.8
# Highlands     1255.0
# Perthshire    1214.0
# Name: Height, dtype: float64
